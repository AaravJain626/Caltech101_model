# %%
import torch
from torch import nn

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.transforms import ToTensor

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.10.0+cpu
# 0.25.0+cpu

# %%
#Device Agnostic Code
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
import scipy
import numpy as np

# %%
data = torchvision.datasets.Caltech101(
    root = "data",
    download = True,
    transform = ToTensor(),
    target_transform = None
)

# %%
# train test split
train_data = data[int(len(data) * 0.8)]
len(x)
# Out:
# 2

# %%
len(train_data)
# Out:
# 1

# %%
len(iter(train_data))
image, label = train_data[1]
image.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_738/4261936531.py in <cell line: 0>()
# ----> 1 len(iter(train_data))
#       2 image, label = train_data[1]
#       3 image.shape
#
# TypeError: object of type 'tuple_iterator' has no len()

# %%
classNames = train_data.categories
classNames[3]
# Out:
# 'Motorbikes'

# %%
#Showing images
import matplotlib.pyplot as plt
image, label = train_data[922]
# The original image is (C, H, W). For imshow, it needs to be (H, W, C) and a numpy array.
plt.imshow(image.permute(1, 2, 0).numpy())
plt.title(f"Label: {classNames[label]}")
plt.axis('off')
plt.show()

# %%
image.size()
# Out:
# torch.Size([3, 128, 192])

# %%
from torch.utils.data import DataLoader
BATCH_SIZE = 16

train_dataloader = DataLoader(dataset=train_data,
                              batch_size=BATCH_SIZE,
                              shuffle=True

)
test_dataloader  = DataLoader(dataset=test_data,
                              batch_size=BATCH_SIZE,
                              shuffle=True

)
print(f"Length of Dataset: {len(train_data)}")
print(f"Length of Dataloader: {len(train_dataloader)}")
# Out:
# Length of Dataset: 8677
# Length of Dataloader: 543

# %%
flatten_model = nn.Flatten()
